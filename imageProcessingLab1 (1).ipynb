# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\z-hay\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in c:\users\z-hay\anaconda3\lib\site-packages (from opencv-python) (2.1.3)

# %%
import cv2
img1 = cv2.imread('image1.png')

# %%
import matplotlib.pyplot as plt
plt.imshow(img1)
plt.show()

# %%
from PIL import Image
img2 = Image.open('image1.png')

import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %%
cv2.imwrite('new_image.jpg', img1)
# Out:
# True

# %%
img2.save('new_image2.jpg')

# %%
print(img1.shape)
print(img1)
# Out:
# (350, 625, 3)
# [[[233 177 128]
#   [233 177 128]
#   [233 177 128]
#   ...
#   [169 100  27]
#   [169 100  27]
#   [168 100  27]]
#
#  [[235 179 130]
#   [235 179 130]
#   [235 179 130]
#   ...
#   [169 100  27]
#   [169 100  27]
#   [168 100  27]]
#
#  [[236 180 133]
#   [236 180 133]
#   [236 180 133]
#   ...
#   [170 102  27]
#   [170 102  27]
#   [169 102  27]]
#
#  ...
#
#  [[ 18  54  37]
#   [ 11  47  30]
#   [ 20  56  40]
#   ...
#   [ 14  22  21]
#   [ 25  30  31]
#   [ 15  20  21]]
#
#  [[ 36  71  51]
#   [ 12  46  29]
#   [ 20  53  38]
#   ...
#   [ 20  28  28]
#   [ 18  23  26]
#   [ 20  28  27]]
#
#  [[ 42  74  55]
#   [  5  37  18]
#   [ 19  50  35]
#   ...
#   [ 23  30  33]
#   [ 14  19  22]
#   [ 12  20  19]]]

# %%
import numpy as np
img_array = np.array(img2)

# %%
print(img_array.shape)
print(img_array)
# Out:
# (350, 625, 3)
# [[[128 177 233]
#   [128 177 233]
#   [128 177 233]
#   ...
#   [ 27 100 169]
#   [ 27 100 169]
#   [ 27 100 168]]
#
#  [[130 179 235]
#   [130 179 235]
#   [130 179 235]
#   ...
#   [ 27 100 169]
#   [ 27 100 169]
#   [ 27 100 168]]
#
#  [[133 180 236]
#   [133 180 236]
#   [133 180 236]
#   ...
#   [ 27 102 170]
#   [ 27 102 170]
#   [ 27 102 169]]
#
#  ...
#
#  [[ 37  54  18]
#   [ 30  47  11]
#   [ 40  56  20]
#   ...
#   [ 21  22  14]
#   [ 31  30  25]
#   [ 21  20  15]]
#
#  [[ 51  71  36]
#   [ 29  46  12]
#   [ 38  53  20]
#   ...
#   [ 28  28  20]
#   [ 26  23  18]
#   [ 27  28  20]]
#
#  [[ 55  74  42]
#   [ 18  37   5]
#   [ 35  50  19]
#   ...
#   [ 33  30  23]
#   [ 22  19  14]
#   [ 19  20  12]]]
